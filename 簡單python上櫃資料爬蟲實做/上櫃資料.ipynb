# %%
import requests

link = 'http://www.tpex.org.tw/web/stock/aftertrading/daily_close_quotes/stk_quote_download.php?l=zh-tw&d=107/02/09&s=0,asc,0'
r = requests.get(link)
r.ok
# Out:
# True

# %%
lines = r.text.replace('\r', '').split('\n')

import pandas as pd
from io import StringIO
df = pd.read_csv(StringIO("\n".join(lines[3:])), sep=',', delimiter=',', header=None)
df.head()
# Out:
#        0         1      2       3      4      5      6      7        8   \
# 0  006201    元大富櫃50  13.70  -0.03   13.03  13.70  13.03  13.46   55,000
# 1  00679B   元大美債20年  36.11   +0.02  36.05  36.12  36.00  36.05  855,000
# 2  00687B   國泰20年美債  37.19  -0.11   37.21  37.22  37.19  37.20  926,000
# 3  00694B   富邦美債1-3  38.78   +0.13  38.80  38.80  38.76  38.76  502,000
# 4  00695B  富邦美債7-10  37.23   +0.10  37.22  37.23  37.22  37.22  500,000
#
#            9   10     11     12           13     14       15     16
# 0     740,100  28  13.62  13.70   13,946,000  13.70    15.07  12.33
# 1  30,820,670  95  36.07  36.11  673,192,000  36.11  9999.95   0.01
# 2  34,450,170  17  37.20  37.23  183,787,000  37.19  9999.95   0.01
# 3  19,457,580   6  38.71  38.78   98,576,000  38.78  9999.95   0.01
# 4  18,611,100   8  37.20  37.27   10,686,000  37.23  9999.95   0.01

# %%
df.columns = list(map(lambda l: l.replace(' ',''), lines[2].split(',')))
df.index = df['代號']
df = df.drop(['代號'], axis=1)
df.head()
# Out:
#               名稱     收盤      漲跌     開盤     最高     最低     均價     成交股數  \
# 代號
# 006201    元大富櫃50  13.70  -0.03   13.03  13.70  13.03  13.46   55,000
# 00679B   元大美債20年  36.11   +0.02  36.05  36.12  36.00  36.05  855,000
# 00687B   國泰20年美債  37.19  -0.11   37.21  37.22  37.19  37.20  926,000
# 00694B   富邦美債1-3  38.78   +0.13  38.80  38.80  38.76  38.76  502,000
# 00695B  富邦美債7-10  37.23   +0.10  37.22  37.23  37.22  37.22  500,000
#
#            成交金額(元) 成交筆數   最後買價   最後賣價         發行股數  次日參考價    次日漲停價  次日跌停價
# 代號
# 006201     740,100   28  13.62  13.70   13,946,000  13.70    15.07  12.33
# 00679B  30,820,670   95  36.07  36.11  673,192,000  36.11  9999.95   0.01
# 00687B  34,450,170   17  37.20  37.23  183,787,000  37.19  9999.95   0.01
# 00694B  19,457,580    6  38.71  38.78   98,576,000  38.78  9999.95   0.01
# 00695B  18,611,100    8  37.20  37.27   10,686,000  37.23  9999.95   0.01

# %%
df.to_csv('test.csv')
pd.read_csv('test.csv', index_col='代號').head()
# Out:
#               名稱     收盤      漲跌     開盤     最高     最低     均價     成交股數  \
# 代號
# 006201    元大富櫃50  13.70  -0.03   13.03  13.70  13.03  13.46   55,000
# 00679B   元大美債20年  36.11   +0.02  36.05  36.12  36.00  36.05  855,000
# 00687B   國泰20年美債  37.19  -0.11   37.21  37.22  37.19  37.20  926,000
# 00694B   富邦美債1-3  38.78   +0.13  38.80  38.80  38.76  38.76  502,000
# 00695B  富邦美債7-10  37.23   +0.10  37.22  37.23  37.22  37.22  500,000
#
#            成交金額(元) 成交筆數   最後買價   最後賣價         發行股數  次日參考價    次日漲停價  次日跌停價
# 代號
# 006201     740,100   28  13.62  13.70   13,946,000  13.70    15.07  12.33
# 00679B  30,820,670   95  36.07  36.11  673,192,000  36.11  9999.95   0.01
# 00687B  34,450,170   17  37.20  37.23  183,787,000  37.19  9999.95   0.01
# 00694B  19,457,580    6  38.71  38.78   98,576,000  38.78  9999.95   0.01
# 00695B  18,611,100    8  37.20  37.27   10,686,000  37.23  9999.95   0.01
